# %%
import pandas as pd
import numpy as np
from statsmodels.stats.weightstats import ttest_ind,ztest

# %%
purchase_df=pd.read_csv(r'D:\COURSES\AI\Epsilon Ai\Session 20\data\Ecommerce Purchases.csv')
purchase_df
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
purchase_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
purchase_df.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
purchase_df.tail()
# Out:
#                                                 Address    Lot AM or PM  \
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 9995  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/5352 ...
# 9996  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 9997  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_7...
# 9998  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_8;...
# 9999  Mozilla/5.0 (X11; Linux i686; rv:1.9.5.20) Gec...
#
#                        Company       Credit Card CC Exp Date  \
# 9995             Randall-Sloan   342945015358701       03/22
# 9996  Hale, Collins and Wilson   210033169205009       07/25
# ...

# %%
purchase_df.describe()
# Out:
#         Credit Card  CC Security Code  Purchase Price
# count  1.000000e+04      10000.000000    10000.000000
# mean   2.341374e+15        907.217800       50.347302
# std    2.256103e+15       1589.693035       29.015836
# min    6.040186e+10          0.000000        0.000000
# 25%    3.056322e+13        280.000000       25.150000
# 50%    8.699942e+14        548.000000       50.505000
# 75%    4.492298e+15        816.000000       75.770000
# max    6.012000e+15       9993.000000       99.990000

# %%
purchase_df['Purchase Price'].mean()
# Out:
# 50.347302

# %%
purchase_df['Purchase Price'].std()
# Out:
# 29.01583630978903

# %%
purchase_df['Purchase Price'].var()
# Out:
# 841.9187567564716

# %%
purchase_df['Job'].mode()
# Out:
# 0    Interior and spatial designer
# Name: Job, dtype: object

# %%
purchase_df['Job'].value_counts()
# Out:
# Job
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
#                                  ..
# Prison officer                    7
# Editor, film/video                6
# Actuary                           6
# Information systems manager       5
# Investment analyst                5
# Name: count, Length: 623, dtype: int64

# %%
purchase_df[purchase_df['Job']=='Lawyer']['Purchase Price'].mean()
# Out:
# 53.46166666666666

# %%
purchase_df.groupby('Job')['Purchase Price'].mean().reset_index().sort_values(by='Purchase Price',ascending=False)
# Out:
#                                   Job  Purchase Price
# 602               Trade mark attorney       73.802727
# 606                        Translator       70.777647
# 315                Investment analyst       69.090000
# 4    Accountant, chartered management       69.082667
# 149      Designer, industrial/product       68.714667
# ..                                ...             ...
# 586             Theatre stage manager       31.580000
# 170         Editor, magazine features       31.445294
# 206              Engineer, production       27.771667
# 48                Art gallery manager       27.381250
# 352               Marketing executive       26.008889
#
# [623 rows x 2 columns]

# %%
averg_pr=purchase_df.groupby('Job')['Purchase Price'].mean()

# %%
averg_pr[averg_pr==averg_pr.max()]
# Out:
# Job
# Trade mark attorney    73.802727
# Name: Purchase Price, dtype: float64

# %%
averg_pr[averg_pr==averg_pr.max()].index[0]
# Out:
# 'Trade mark attorney'

# %%
purchase_df.columns=purchase_df.columns.str.lower().str.replace(' ','_')
purchase_df
# Out:
#                                                 address    lot am_or_pm  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            browser_info  \
# ...

# %%
purchase_df
# Out:
#                                                 address    lot am_or_pm  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            browser_info  \
# ...

# %%
purchase_df.to_csv('Purchase_ee.csv')

# %% [markdown]
# Tasking...:
# What is the average Purchase Price?
#
# What were the highest and lowest purchase prices?
#
# How many people have English 'en' as their Language of choice on the website?
#
# How many people have the job title of "Lawyer" ?
#
# How many people made the purchase during the AM and how many people made the purchase during PM ?
#
# What are the 5 most common Job Titles?
#
# Someone made a purchase that came from Lot: "90 WT" , what was the Purchase Price for this transaction?
#
# What is the email of the person with the following Credit Card Number: 4926535242672853
#
# How many people have American Express as their Credit Card Provider and made a purchase above $95 ?
#
# Hard: How many people have a credit card that expires in 2025?

# %%
purchase_df.purchase_price.mean()
# Out:
# 50.347302

# %%
purchase_df.purchase_price.describe()
# Out:
# count    10000.000000
# mean        50.347302
# std         29.015836
# min          0.000000
# 25%         25.150000
# 50%         50.505000
# 75%         75.770000
# max         99.990000
# Name: purchase_price, dtype: float64

# %%
purchase_df.purchase_price.min(),purchase_df.purchase_price.max()
# Out:
# (0.0, 99.99)

# %%
purchase_df.language.value_counts()[purchase_df.language.value_counts().index=='en']
# Out:
# language
# en    1098
# Name: count, dtype: int64

# %%
purchase_df.language.value_counts().loc['en']
# Out:
# 1098

# %%
purchase_df.job.value_counts().loc['Lawyer']
# Out:
# 30

# %%
purchase_df.am_or_pm.value_counts().loc['AM'],purchase_df.am_or_pm.value_counts().loc['PM']
# Out:
# (4932, 5068)

# %%
float(purchase_df[purchase_df.lot=="90 WT"].purchase_price.values)
# Out:
# 75.1

# %%
str(purchase_df[purchase_df.credit_card==4926535242672853].email.values[0])
# Out:
# 'bondellen@williams-garza.com'

# %%
len(purchase_df[(purchase_df.cc_provider=='American Express') & (purchase_df.purchase_price>95)])
# Out:
# 39

# %%
purchase_df[(purchase_df.cc_provider=='American Express') & (purchase_df.purchase_price>95)].credit_card.nunique()
# Out:
# 39

# %%
purchase_df.shape[0]-purchase_df.cc_exp_date.apply(lambda x: x.split('/')[1]=='25').sum()
# Out:
# 8967

# %%
purchase_df['dd']=pd.to_datetime(purchase_df['cc_exp_date'],format='%m/%y')
purchase_df
# Out:
#                                                 address    lot am_or_pm  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            browser_info  \
# ...

# %%
list(purchase_df.email.apply(lambda x: x.split('@')[1]).value_counts().head(5).index)
# Out:
# ['hotmail.com', 'yahoo.com', 'gmail.com', 'smith.com', 'williams.com']
